# %% [markdown]
# ReadME:
#         1. Keep all the files in one folder, i.e.,Analytic_codingtest's_Solution, t.json.gz and y.json.gz
#         2. Run all Scripts once (Cell:Run All)
#         3. Few descriptions and questions are written in Markdowns and headings.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# Reading both files and cleaning the columns which are required for now.

# %%
td = pd.read_json('t.json.gz', orient='records', lines=True)
td['available_price'].fillna(td['available_price'].mean(),inplace=True)
td['mrp'].fillna(td['mrp'].mean(),inplace=True)
td.describe()
td.head()
# Out:
#    available_price   category  crawl_date  http_status  mrp pack_size  \
# 0             5.99  Household    20180727          200  0.0     30 ct
# 1             5.49  Household    20180727          200  0.0     25 ct
# 2             5.69  Household    20180727          200  0.0   30.0 ct
# 3             5.99  Household    20180727          200  0.0     12 ct
# 4             5.99  Household    20180727          200  0.0     20 ct
#
#            subcategory                                              title  \
# 0  Trash Bags & Liners  Seventh Generation 13 Gallon Extra Strong Flap...
# 1  Trash Bags & Liners  BioBag Food Scrap Bags Small 3 Gallon - 25 CT ...
# 2  Trash Bags & Liners  If You Care Certified Compostable Food Waste B...
# 3  Trash Bags & Liners  BioBag Food Scrap Bags Tall Kitchen 13 Gallon ...
# 4  Trash Bags & Liners  Seventh Generation 13 Gal with Drawstring Clos...
#
#                                        urlh
# 0  1ef0f41ebcee030a35440405f2f8b0165c719c89
# 1  c566570abdbe95b5e6a78eb8b3b2424108bf36a2
# 2  3b22b28b351dec75664b17fcf586023ddc21704c
# 3  7ff787f49e137237054f95e7cb5b0f8611e7f6fb
# 4  a7ad16e71257855c033aad46eb5082a2153b97c6

# %%
yd = pd.read_json('y.json.gz', orient='records', lines=True)
yd['available_price'].fillna(yd['available_price'].mean(),inplace=True)
yd['mrp'].fillna(yd['mrp'].mean(),inplace=True)
yd.describe()
# Out:
#        available_price  crawl_date    http_status            mrp
# count    141699.000000    141699.0  141699.000000  141699.000000
# mean          8.305921  20180726.0     200.012011       0.615633
# std          12.210145         0.0       1.618499       3.096523
# min           0.000000  20180726.0     200.000000       0.000000
# 25%           3.390000  20180726.0     200.000000       0.000000
# 50%           5.290000  20180726.0     200.000000       0.000000
# 75%           9.190000  20180726.0     200.000000       0.000000
# max         799.990000  20180726.0     502.000000      99.990000

# %% [markdown]
# # 1. No of URLH which are overlapping.

# %%
td['is_urlh_duplicate']=td.duplicated('urlh')
x= td['is_urlh_duplicate'].sum()
print("Number of overlapping URLH's from today's data are "+str(x))
# Out:
# Number of overlapping URLH's from today's data are 10802

# %%
yd['is_urlh_duplicate']=yd.duplicated('urlh')
x=yd['is_urlh_duplicate'].sum()
#yd['urlh']
print("Number of overlapping URLH's from yesterday's data are "+str(x))
# Out:
# Number of overlapping URLH's from yesterday's data are 10781

# %%
#td_org = td.loc[td['is_urlh_duplicate']==False]
#yd_org = yd.loc[yd['is_urlh_duplicate']==False]
td_clean=td[td['is_urlh_duplicate']==False]
yd_clean=yd[yd['is_urlh_duplicate']==False]
clean_urlh = pd.concat([td_clean['urlh'],yd_clean['urlh']],axis=1,keys = ['td','yd'])
overlap_urlh = clean_urlh[clean_urlh.td == clean_urlh.yd]
print("Number of overlapping URLH's from yesterday to today are "+str(overlap_urlh.td.count()))
# Out:
# Number of overlapping URLH's from yesterday to today are 306

# %% [markdown]
# # 2. For all the URLH which are overlapping, calculate the price difference (w.r.t available_price) if there is any between yesterday's and today's crawls.

# %%
price_difference = yd_clean['available_price'] - td_clean['available_price']
price_difference.dropna(axis=0,how='any',inplace=True)
print("The price difference between the URLH's which are overlapping between yesterday and today are:")
price_difference
#yd.dropna(axis=0,how='any',inplace=True)
# Out:
# The price difference between the URLH's which are overlapping between yesterday and today are:
# 0          0.00
# 1          0.00
# 2          0.00
# 3          0.00
# 4          0.00
# 5          0.00
# 6          0.00
# 7          0.00
# 8          0.00
# 9          0.00
# 10         0.00
# 11         0.00
# 12         0.00
# 13         0.00
# 14         0.00
# 15         0.00
# 16         0.00
# 17         0.00
# 18         0.00
# 19         0.00
# 20         0.00
# 21         0.00
# 22         0.00
# 23         0.00
# 24         0.00
# 25        -0.10
# 26         1.80
# 27         0.00
# 28         0.00
# 29        -2.00
#           ...
# 141660   -21.80
# 141661    -4.50
# 141663    -9.50
# 141665     4.70
# 141666   -13.12
# 141667     6.72
# 141670     7.50
# 141672     8.00
# 141673    -5.00
# 141674    -1.50
# 141676     9.00
# 141678     1.70
# 141679    -6.00
# 141680    14.10
# 141681     5.90
# 141682     6.80
# 141683    -3.30
# 141684    -5.00
# 141685    -5.30
# 141686    -5.00
# 141687    -1.00
# 141688    -1.50
# 141689    -7.00
# 141690    -4.50
# 141691   -11.50
# 141692    23.00
# 141693    -5.80
# 141694     2.01
# 141695    -5.80
# 141696     1.20
# Name: available_price, Length: 125681, dtype: float64

# %% [markdown]
# A scatter plot which shows the range of difference price.

# %%
price = pd.DataFrame(price_difference)
price['index']=price.index
plt.scatter(price['index'],price['available_price'])
plt.xlabel("No. of Prices")
plt.ylabel("Difference in prices")
# Out:
# Text(0,0.5,'Difference in prices')

# %% [markdown]
# # 3. No of Unique categories in both files.
# # 4. List of categories which is not overlapping.

# %%
td_unique_categories = td['category'].unique()
yd_unique_categories = yd['category'].unique()
today_unique_categories = pd.DataFrame(td_unique_categories)
yesterday_unique_categories = pd.DataFrame(yd_unique_categories)
today_unique_categories.rename(columns={0:'Today'},inplace=True)
yesterday_unique_categories.rename (columns={0:'Yesterday'},inplace=True)
print ("Number of Unique categories in today's file is "+str(today_unique_categories.count()[0]))
print ("Number of Unique categories in yesterdays's file is "+str(yesterday_unique_categories.count()[0]))
list_cat = pd.concat([today_unique_categories,yesterday_unique_categories],axis=1)
print ("List of Categories from both files which are not overlapping are in table below")
list_cat
# Out:
# Number of Unique categories in today's file is 50
# Number of Unique categories in yesterdays's file is 50
# List of Categories from both files which are not overlapping are in table below
#                             Today                      Yesterday
# 0                       Household                      Household
# 1                            Pets                           Pets
# 2                          Babies                         Babies
# 3                   Personal Care                  Personal Care
# 4                       Breakfast                      Breakfast
# 5                   International                  International
# 6               Dry Goods & Pasta              Dry Goods & Pasta
# 7                            Bulk                           Bulk
# 8                    Canned Goods                   Canned Goods
# 9                          Pantry                         Pantry
# 10                 Meat & Seafood                 Meat & Seafood
# 11                         Bakery                         Bakery
# 12                         Frozen                         Frozen
# 13                      Beverages                      Beverages
# 14                         Snacks                         Snacks
# 15                           Deli                           Deli
# 16                   Dairy & Eggs                   Dairy & Eggs
# 17                        Produce                        Produce
# 18              Holiday Favorites              Holiday Favorites
# 19      Allergy & Cold Essentials      Allergy & Cold Essentials
# 20                      Christmas                      Christmas
# 21                        Alcohol                        Alcohol
# 22                           Food                           Food
# 23        Glassware & Accessories        Glassware & Accessories
# 24       Coolers & Malt Beverages       Coolers & Malt Beverages
# 25                          Cider                          Cider
# 26                  Variety Packs                  Variety Packs
# 27  Seasonal/Special Release Beer  Seasonal/Special Release Beer
# 28           Specialty Style Beer           Specialty Style Beer
# 29            Gift Baskets & Sets            Gift Baskets & Sets
# 30                 Ready to Drink                 Ready to Drink
# 31     Liqueurs/Cordials/Schnapps     Liqueurs/Cordials/Schnapps
# 32                Brandy & Cognac                Brandy & Cognac
# 33                         Scotch                         Scotch
# 34                        Bourbon                        Bourbon
# 35                            Rum                            Rum
# 36                        Tequila                        Tequila
# 37               Sake & Plum Wine               Sake & Plum Wine
# 38                     Fruit Wine                     Fruit Wine
# 39       Dessert & Fortified Wine       Dessert & Fortified Wine
# 40               American Whiskey               American Whiskey
# 41           Mixers, Water & Soda           Mixers, Water & Soda
# 42     Champagne & Sparkling Wine     Champagne & Sparkling Wine
# 43                       Ale Beer                       Ale Beer
# 44                          Vodka                          Vodka
# 45                     Lager Beer                     Lager Beer
# 46                     White Wine                     White Wine
# 47                       Red Wine                       Red Wine
# 48                        Grocery                        Grocery
# 49                   Baby & Child                   Baby & Child

# %% [markdown]
# # 5. Generate the stats with count for all taxonomies (taxonomy is concatenation of category and subcategory separated by " > ").

# %%
tt = pd.DataFrame (td['category'])
tt['subcategory']=td['subcategory']
taxo = tt.groupby('category')['subcategory'].value_counts()
cate = taxo.index.get_level_values(level=0)
subcate = taxo.index.get_level_values(level=1)
cnt = taxo.values
print ("The statistic with category, subcategory and their counts for today's file :\n\n")
for i in range (0,len(cnt)-1):
    print(cate[i],'>',subcate[i],':',cnt[i])
    i+=1
# Out:
# The statistic with category, subcategory and their counts for today's file :
#
#
# Alcohol > Red Wines : 224
# Alcohol > Beers & Coolers : 197
# Alcohol > White Wines : 63
# Alcohol > Specialty Wines & Champagnes : 45
# Alcohol > Rosés : 26
# Alcohol > Cocktail Mixes : 7
# Alcohol > Spirits : 5
# Ale Beer > IPA (India Pale Ale) : 389
# Ale Beer > Belgian-Style Ale : 142
# Ale Beer > Pale Ale : 115
# Ale Beer > Wheat Ale : 101
# Ale Beer > Stout : 85
# Ale Beer > Amber/Red Ale : 63
# Ale Beer > Blond Ale : 59
# Ale Beer > Strong Ale & Barley Wine : 54
# Ale Beer > Porter : 38
# Ale Beer > Brown Ale : 24
# Allergy & Cold Essentials > Allergy : 52
# Allergy & Cold Essentials > Essentials : 34
# Allergy & Cold Essentials > Pain & Fever : 31
# Allergy & Cold Essentials > Cough & Cold Medicine : 30
# American Whiskey > Whiskey : 226
# American Whiskey > Other : 87
# American Whiskey > Rye Whiskey : 76
# American Whiskey > Tennessee Whiskey : 31
# Babies > Baby Food & Formula : 1294
# Babies > Diapers & Wipes : 543
# Babies > Baby Bath & Body Care : 285
# Babies > Baby Accessories : 253
# Babies > Baby First Aid & Vitamins : 197
# Baby & Child > Diapers & Wipes : 98
# Baby & Child > Baby Bath & Body Care : 66
# Baby & Child > Baby First Aid & Vitamins : 47
# Baby & Child > Baby Food & Formula : 25
# Baby & Child > Baby Accessories : 19
# Bakery > Bread : 1194
# Bakery > Bakery Desserts : 1048
# Bakery > Breakfast Bakery : 509
# Bakery > Buns & Rolls : 417
# Bakery > Tortillas & Flat Bread : 398
# Beverages > Juice & Nectars : 2224
# Beverages > Coffee : 2052
# Beverages > Tea : 1877
# Beverages > Soft Drinks : 1567
# Beverages > Water, Seltzer & Sparkling Water : 1212
# Beverages > Refrigerated : 1189
# Beverages > Energy & Sports Drinks : 984
# Beverages > Cocoa & Drink Mixes : 495
# Bourbon > Small Batch Bourbon : 140
# Bourbon > Other : 101
# Brandy & Cognac > Cognac : 88
# Brandy & Cognac > Brandy : 57
# Brandy & Cognac > Flavored Brandy : 21
# Brandy & Cognac > Calvados : 11
# Brandy & Cognac > Armagnac : 7
# Brandy & Cognac > Grappa : 7
# Brandy & Cognac > Eau de Vie : 3
# Brandy & Cognac > Other : 2
# Brandy & Cognac > Pisco : 2
# Breakfast > Cereal : 1144
# Breakfast > Hot Cereal & Pancake Mixes : 557
# Breakfast > Breakfast Bars & Pastries : 393
# Breakfast > Granola : 346
# Bulk > Bulk Nuts & Seeds : 242
# Bulk > Bulk Grains, Rice & Dried Beans : 196
# Bulk > Bulk Tea & Coffee : 169
# Bulk > Bulk Flours & Powders : 139
# Bulk > Bulk Spices & Seasonings : 133
# Bulk > Bulk Dried Fruits & Vegetables : 83
# Bulk > Bulk Candies & Chocolates : 77
# Bulk > Bulk Trail Mix & Snack Mix : 61
# Bulk > Bulk Grains, Rice & Dried Goods : 57
# Bulk > Other Bulk : 46
# Bulk > Bulk Granola & Cereals : 30
# Bulk > Bulk Spreads Butter, Honey, Syrup : 19
# Bulk > Bulk Sugar & Sweeteners : 14
# Bulk > Bulk Pasta : 11
# Bulk > Bulk Soup Mix : 10
# Bulk > Bulk Containers : 5
# Bulk > Bulk Spices & Seasoning : 5
# Bulk > Bulk Home & Personal Care : 3
# Canned Goods > Soup, Broth & Bouillon : 1594
# Canned Goods > Canned & Jarred Vegetables : 950
# Canned Goods > Canned Meals & Beans : 797
# Canned Goods > Canned Meat & Seafood : 636
# Canned Goods > Canned Fruit & Applesauce : 543
# Champagne & Sparkling Wine > Sparkling Wine : 165
# Champagne & Sparkling Wine > Champagne : 107
# Champagne & Sparkling Wine > Sparkling Red Wine : 45
# Champagne & Sparkling Wine > Prosecco : 41
# Champagne & Sparkling Wine > Cava : 38
# Champagne & Sparkling Wine > Flavored Sparkling Wine : 34
# Champagne & Sparkling Wine > Muscat/Moscato : 30
# Christmas > Christmas : 5392
# Cider > Apple Cider : 118
# Cider > Other Fruit Cider : 81
# Cider > Perry (Pear Cider) : 22
# Coolers & Malt Beverages > Flavored Malt Beverages : 60
# Coolers & Malt Beverages > Wine Coolers : 7
# Dairy & Eggs > Yogurt : 1816
# Dairy & Eggs > Packaged Cheese : 1605
# Dairy & Eggs > Milk : 708
# Dairy & Eggs > Soy & Lactose-Free : 560
# Dairy & Eggs > Other Creams & Cheeses : 417
# Dairy & Eggs > Cream : 348
# Dairy & Eggs > Butter : 289
# Dairy & Eggs > Refrigerated Pudding & Desserts : 186
# Dairy & Eggs > Eggs : 179
# Dairy & Eggs > Dairy Alternatives : 115
# Dairy & Eggs > Tofu & Meat Alternatives : 72
# Deli > Prepared Meals : 1273
# Deli > Specialty Cheeses : 957
# Deli > Lunch Meat : 827
# Deli > Prepared Soups & Salads : 439
# Deli > Fresh Dips & Tapenades : 416
# Deli > Tofu & Meat Alternatives : 103
# Deli > Deli Meat : 83
# Deli > Newly Added : 5
# Dessert & Fortified Wine > Port : 72
# Dessert & Fortified Wine > Vermouth : 35
# Dessert & Fortified Wine > Bordeaux Blend : 32
# Dessert & Fortified Wine > Mead : 27
# Dessert & Fortified Wine > Aperitif : 25
# Dessert & Fortified Wine > Sherry : 22
# Dessert & Fortified Wine > Riesling : 13
# Dessert & Fortified Wine > Other Dessert & Fortified Wines : 11
# Dessert & Fortified Wine > Muscat/Muscadine : 10
# Dessert & Fortified Wine > Fruit-Based Dessert Wine : 8
# Dessert & Fortified Wine > Ice Wine : 8
# Dessert & Fortified Wine > Red Blend Dessert Wine : 7
# Dessert & Fortified Wine > White Blend Dessert Wine : 6
# Dessert & Fortified Wine > Chocolate Wine : 3
# Dessert & Fortified Wine > Marsala : 3
# Dessert & Fortified Wine > Madeira : 2
# Dry Goods & Pasta > Instant Foods : 1031
# Dry Goods & Pasta > Dry Pasta : 757
# Dry Goods & Pasta > Pasta Sauce : 713
# Dry Goods & Pasta > Grains, Rice & Dried Goods : 609
# Dry Goods & Pasta > Fresh Pasta : 183
# Dry Goods & Pasta > Spices & Seasoning : 7
# Dry Goods & Pasta > Whole & Ground Seeds : 3
# Dry Goods & Pasta > Baking Supplies : 1
# Food > Chocolate, Candy & Mints : 8
# Food > Nuts : 6
# Food > Cheese : 2
# Food > Oils & Vinegars : 2
# Food > Chips, Puffs & Pretzels : 1
# Food > Condiments : 1
# Frozen > Ice Cream & Ice : 2507
# Frozen > Frozen Meals : 1953
# Frozen > Frozen Produce : 707
# Frozen > Frozen Appetizers & Sides : 685
# Frozen > Frozen Pizza : 593
# Frozen > Frozen Meat & Seafood : 480
# Frozen > Frozen Breakfast : 478
# Frozen > Frozen Vegan & Vegetarian : 378
# Frozen > Frozen Dessert : 299
# Frozen > Frozen Juice : 162
# Frozen > Frozen Breads & Doughs : 113
# Fruit Wine > Fruit Blends : 35
# Fruit Wine > Sangria : 28
# Gift Baskets & Sets > Gift Sets : 5
# Gift Baskets & Sets > Gift Baskets : 3
# Glassware & Accessories > Wine Glassware : 36
# Glassware & Accessories > Wine Accessories : 33
# Glassware & Accessories > Bar Tools : 25
# Glassware & Accessories > Other Glassware : 14
# Glassware & Accessories > Spirits Glassware : 14
# Glassware & Accessories > Beer Glassware : 6
# Glassware & Accessories > Wine Storage & Transport : 5
# Grocery > Frozen : 27
# Grocery > Pasta & Pasta Sauce : 12
# Grocery > Instant Foods : 11
# Grocery > Nuts : 7
# Grocery > Bars : 2
# Grocery > Bakery & Bread : 1
# Grocery > Sugar & Sugar Substitutes : 1
# Holiday Favorites > Produce : 32
# Holiday Favorites > Holiday Pantry : 22
# Holiday Favorites > Cheese & Appetizers : 11
# Holiday Favorites > Candles & Kitchenwares : 10
# Holiday Favorites > Desserts & Bakery : 6
# Holiday Favorites > Entrees : 5
# Holiday Favorites > Beverages : 3
# Holiday Favorites > Sides & Salads : 3
# Household > More Household : 3950
# Household > Cleaning Products : 1542
# Household > Kitchen Supplies : 1163
# Household > Laundry : 1051
# Household > Air Fresheners & Candles : 809
# Household > Food Storage : 629
# Household > Paper Goods : 601
# Household > Plates, Bowls, Cups & Flatware : 500
# Household > Dish Detergents : 391
# Household > Trash Bags & Liners : 175
# Household > Garden : 57
# Household > Books & Magazines : 1
# International > Asian Foods : 945
# International > Latino Foods : 480
# International > Kosher Foods : 179
# International > Indian Foods : 148
# International > More International Foods : 21
# Lager Beer > American-Style Lager : 110
# Lager Beer > Czech & German Pilsner : 79
# Lager Beer > Light Lager : 62
# Lager Beer > Euro Pale Lager : 42
# Lager Beer > Other Dark Lager : 26
# Lager Beer > Other Pale Lager : 25
# Lager Beer > Amber/Red Lager : 18
# Lager Beer > American All-Malt Lager : 16
# Lager Beer > Bock/Doppelbock/Maibock : 12
# Lager Beer > Japanese Rice Lager : 5
# Liqueurs/Cordials/Schnapps > Herbal & Spice : 111
# Liqueurs/Cordials/Schnapps > Citrus & Triple Sec : 73
# Liqueurs/Cordials/Schnapps > Cream : 64
# Liqueurs/Cordials/Schnapps > Fruit : 63
# Liqueurs/Cordials/Schnapps > Chocolate; Sweets & Candy : 49
# Liqueurs/Cordials/Schnapps > Nuts & Amaretto : 37
# Liqueurs/Cordials/Schnapps > Coffee : 32
# Liqueurs/Cordials/Schnapps > Fruit Blends : 27
# Liqueurs/Cordials/Schnapps > Unique Flavors : 13
# Liqueurs/Cordials/Schnapps > Other : 12
# Liqueurs/Cordials/Schnapps > Coconut : 4
# Meat & Seafood > Hot Dogs, Bacon & Sausage : 910
# Meat & Seafood > Packaged Meat : 628
# Meat & Seafood > Meat Counter : 397
# Meat & Seafood > Packaged Poultry : 304
# Meat & Seafood > Packaged Seafood : 219
# Meat & Seafood > Meat : 198
# Meat & Seafood > Poultry Counter : 162
# Meat & Seafood > Seafood Counter : 162
# Meat & Seafood > Seafood : 66
# Meat & Seafood > Poultry : 46
# Mixers, Water & Soda > Water : 40
# Mixers, Water & Soda > Tonic Water : 12
# Mixers, Water & Soda > Juice : 10
# Mixers, Water & Soda > Sparkling Cider : 9
# Mixers, Water & Soda > Bitters : 8
# Mixers, Water & Soda > Cocktail Mixes : 8
# Mixers, Water & Soda > Club Soda : 5
# Mixers, Water & Soda > Soda : 5
# Mixers, Water & Soda > Seltzer Water : 4
# Mixers, Water & Soda > Syrups : 2
# Mixers, Water & Soda > Cocktail Rimmers : 1
# Mixers, Water & Soda > Sports Drinks : 1
# Pantry > Spices & Seasonings : 1977
# Pantry > Condiments : 1467
# Pantry > Salad Dressing & Toppings : 1182
# Pantry > Baking Ingredients : 1157
# Pantry > Spreads : 974
# Pantry > Oils & Vinegars : 948
# Pantry > Marinades & Meat Preparation : 891
# Pantry > Doughs, Gelatins & Bake Mixes : 831
# Pantry > Pickled Goods & Olives : 784
# Pantry > Baking Supplies & Decor : 749
# Pantry > Preserved Dips & Spreads : 632
# Pantry > Honeys, Syrups & Nectars : 465
# Personal Care > Beauty : 5731
# Personal Care > Hair Care : 4369
# Personal Care > Vitamins & Supplements : 4247
# Personal Care > Body Lotions & Soap : 2431
# Personal Care > Oral Hygiene : 1978
# Personal Care > Facial Care : 1659
# Personal Care > Cold, Flu & Allergy : 1218
# Personal Care > First Aid : 1185
# Personal Care > Digestion : 1146
# Personal Care > Feminine Care : 1119
# Personal Care > Muscles, Joints & Pain Relief : 991
# Personal Care > Deodorants : 882
# Personal Care > Shave Needs : 774
# Personal Care > Protein & Meal Replacements : 728
# Personal Care > Eye & Ear Care : 660
# Personal Care > Soap : 299
# Personal Care > Family Planning : 259
# Personal Care > Stress & Sleep Aids : 259
# Personal Care > Skin Care : 250
# Personal Care > Hand Care : 243
# Personal Care > Foot Care : 139
# Personal Care > Air Fresheners & Candles : 94
# Personal Care > Adult Care : 67
# Personal Care > Oils & Tinctures : 52
# Personal Care > Medical Supplies/Aid : 46
# Personal Care > Aromatherapy : 34
# Personal Care > Clothing : 34
# Personal Care > Cleanses & Detoxes : 28
# Personal Care > Sun Care : 12
# Pets > Dog Food & Care : 1540
# Pets > Cat Food & Care : 1281
# Pets > Small Animal Care : 153
# Produce > Fresh Vegetables : 1173
# Produce > Packaged Vegetables & Fruits : 991
# Produce > Fresh Fruits : 723
# Produce > Fresh Herbs : 145
# Produce > Tofu & Meat Alternatives : 2
# Ready to Drink > Margaritas : 23
# Ready to Drink > Other : 13
# Ready to Drink > Unique Cocktails : 13
# Ready to Drink > Daiquiris & Rum Drinks : 12
# Ready to Drink > Lemonades & Citrus Drinks : 12
# Ready to Drink > Shots : 9
# Ready to Drink > Chocolate & Cream Drinks : 7
# Ready to Drink > Tea : 5
# Ready to Drink > Mojito : 2
# Ready to Drink > Cosmopolitan : 1
# Ready to Drink > Manhattans & Bourbon Drinks : 1
# Red Wine > Cabernet Sauvignon : 657
# Red Wine > Red Blend : 363
# Red Wine > Pinot Noir : 312
# Red Wine > Bordeaux Blend : 192
# Red Wine > Merlot : 187
# Red Wine > Sangiovese : 162
# Red Wine > Syrah/Shiraz : 148
# Red Wine > Rhone Blend : 96
# Red Wine > Tempranillo : 93
# Red Wine > Zinfandel : 93
# Red Wine > Malbec : 85
# Red Wine > Other Red Wines : 78
# Red Wine > Nebbiolo : 44
# Red Wine > Grenache : 32
# Red Wine > Cabernet Franc : 24
# Red Wine > Gamay : 22
# Red Wine > Corvina : 21
# Red Wine > Barbera : 18
# Red Wine > Petite Sirah : 17
# Red Wine > Montepulciano : 16
# Red Wine > Carmenere : 11
# Red Wine > Mourvedre/Monastrell : 7
# Rum > Aged Rum : 70
# Rum > Flavored Rum : 66
# Rum > Spiced Rum : 52
# Rum > Silver Rum : 43
# Rum > Gold Rum : 23
# Rum > Dark Rum : 16
# Rum > Cachaca : 7
# Rum > Other : 7
# Sake & Plum Wine > Sake : 42
# Sake & Plum Wine > Plum Wine : 6
# Scotch > Single Malt : 103
# Scotch > Blended Scotch : 93
# Seasonal/Special Release Beer > Seasonal : 138
# Seasonal/Special Release Beer > Special Release : 80
# Snacks > Candy & Chocolate : 3085
# Snacks > Chips & Pretzels : 1961
# Snacks > Energy & Granola Bars : 1708
# Snacks > Cookies & Cakes : 1659
# Snacks > Nuts, Seeds & Dried Fruit : 1411
# Snacks > Crackers : 1320
# Snacks > Popcorn & Jerky : 772
# Snacks > Mint & Gum : 501
# Snacks > Fruit & Vegetable Snacks : 464
# Snacks > Trail Mix & Snack Mix : 254
# Snacks > Ice Cream Toppings : 191
# Specialty Style Beer > Specialty Beer : 57
# Specialty Style Beer > Fruit Beer : 37
# Specialty Style Beer > Herbed/Spiced Beer : 21
# Specialty Style Beer > Shandy/Radler : 14
# Specialty Style Beer > American Wild Ale : 8
# Specialty Style Beer > Cream Ale : 3
# Specialty Style Beer > Chili Beer : 2
# Tequila > Blanco/Silver : 96
# Tequila > Reposado : 72
# Tequila > Anejo : 57
# Tequila > Flavored Tequila : 15
# Tequila > Gold : 12
# Tequila > Extra Anejo : 6
# Tequila > Other : 2
# Variety Packs > Variety Packs : 24
# Variety Packs > Gift Sets : 9
# Vodka > Vodka : 325
# Vodka > Flavored Vodka : 261
# Vodka > Other : 9
# Vodka > Variety Packs : 1
# White Wine > Chardonnay : 408
# White Wine > Riesling : 91
# White Wine > Sauvignon Blanc : 89
# White Wine > Pinot Grigio/Pinot Gris : 76
# White Wine > White Blend : 66
# White Wine > Other White Wines : 56
# White Wine > Muscat/Moscato : 41
# White Wine > Chenin Blanc : 17
# White Wine > Bordeaux Blend : 16
# White Wine > Gewurztraminer : 16
# White Wine > Viognier : 15
# White Wine > Rhone Blend : 11
# White Wine > Albarino : 10
# White Wine > Gruner Veltliner : 9
# White Wine > Garganega : 6
# White Wine > Torrontes : 5
# White Wine > Pinot Blanc : 4

# %%
ty = pd.DataFrame (yd['category'])
ty['subcategory']=yd['subcategory']
taxoy = ty.groupby('category')['subcategory'].value_counts()
cat = taxoy.index.get_level_values(level=0)
subcat = taxoy.index.get_level_values(level=1)
cnt1 = taxoy.values
print ("The statistic with category, subcategory and their counts for Yesterday's file :\n\n")
for i in range (0,len(cnt1)-1):
    print(cat[i],'>',subcat[i],':',cnt1[i])
    i+=1
# Out:
# The statistic with category, subcategory and their counts for Yesterday's file :
#
#
# Alcohol > Red Wines : 224
# Alcohol > Beers & Coolers : 197
# Alcohol > White Wines : 63
# Alcohol > Specialty Wines & Champagnes : 45
# Alcohol > Rosés : 26
# Alcohol > Cocktail Mixes : 7
# Alcohol > Spirits : 5
# Ale Beer > IPA (India Pale Ale) : 383
# Ale Beer > Belgian-Style Ale : 139
# Ale Beer > Pale Ale : 107
# Ale Beer > Wheat Ale : 97
# Ale Beer > Stout : 84
# Ale Beer > Amber/Red Ale : 57
# Ale Beer > Blond Ale : 56
# Ale Beer > Strong Ale & Barley Wine : 53
# Ale Beer > Porter : 38
# Ale Beer > Brown Ale : 24
# Allergy & Cold Essentials > Allergy : 52
# Allergy & Cold Essentials > Essentials : 31
# Allergy & Cold Essentials > Pain & Fever : 28
# Allergy & Cold Essentials > Cough & Cold Medicine : 27
# American Whiskey > Whiskey : 226
# American Whiskey > Other : 86
# American Whiskey > Rye Whiskey : 75
# American Whiskey > Tennessee Whiskey : 31
# Babies > Baby Food & Formula : 1296
# Babies > Diapers & Wipes : 538
# Babies > Baby Bath & Body Care : 284
# Babies > Baby Accessories : 252
# Babies > Baby First Aid & Vitamins : 197
# Baby & Child > Diapers & Wipes : 93
# Baby & Child > Baby Bath & Body Care : 65
# Baby & Child > Baby First Aid & Vitamins : 47
# Baby & Child > Baby Food & Formula : 24
# Baby & Child > Baby Accessories : 19
# Bakery > Bread : 1195
# Bakery > Bakery Desserts : 1049
# Bakery > Breakfast Bakery : 509
# Bakery > Buns & Rolls : 418
# Bakery > Tortillas & Flat Bread : 399
# Beverages > Juice & Nectars : 2223
# Beverages > Coffee : 2055
# Beverages > Tea : 1869
# Beverages > Soft Drinks : 1567
# Beverages > Water, Seltzer & Sparkling Water : 1210
# Beverages > Refrigerated : 1188
# Beverages > Energy & Sports Drinks : 979
# Beverages > Cocoa & Drink Mixes : 495
# Bourbon > Small Batch Bourbon : 139
# Bourbon > Other : 98
# Brandy & Cognac > Cognac : 88
# Brandy & Cognac > Brandy : 57
# Brandy & Cognac > Flavored Brandy : 21
# Brandy & Cognac > Calvados : 11
# Brandy & Cognac > Armagnac : 7
# Brandy & Cognac > Grappa : 7
# Brandy & Cognac > Eau de Vie : 3
# Brandy & Cognac > Other : 2
# Brandy & Cognac > Pisco : 2
# Breakfast > Cereal : 1145
# Breakfast > Hot Cereal & Pancake Mixes : 557
# Breakfast > Breakfast Bars & Pastries : 390
# Breakfast > Granola : 346
# Bulk > Bulk Nuts & Seeds : 243
# Bulk > Bulk Grains, Rice & Dried Beans : 195
# Bulk > Bulk Tea & Coffee : 168
# Bulk > Bulk Flours & Powders : 140
# Bulk > Bulk Spices & Seasonings : 133
# Bulk > Bulk Dried Fruits & Vegetables : 83
# Bulk > Bulk Candies & Chocolates : 77
# Bulk > Bulk Trail Mix & Snack Mix : 61
# Bulk > Bulk Grains, Rice & Dried Goods : 57
# Bulk > Other Bulk : 46
# Bulk > Bulk Granola & Cereals : 29
# Bulk > Bulk Spreads Butter, Honey, Syrup : 19
# Bulk > Bulk Sugar & Sweeteners : 14
# Bulk > Bulk Pasta : 11
# Bulk > Bulk Soup Mix : 11
# Bulk > Bulk Containers : 5
# Bulk > Bulk Spices & Seasoning : 5
# Bulk > Bulk Home & Personal Care : 3
# Canned Goods > Soup, Broth & Bouillon : 1591
# Canned Goods > Canned & Jarred Vegetables : 947
# Canned Goods > Canned Meals & Beans : 797
# Canned Goods > Canned Meat & Seafood : 636
# Canned Goods > Canned Fruit & Applesauce : 544
# Champagne & Sparkling Wine > Sparkling Wine : 166
# Champagne & Sparkling Wine > Champagne : 107
# Champagne & Sparkling Wine > Sparkling Red Wine : 45
# Champagne & Sparkling Wine > Prosecco : 41
# Champagne & Sparkling Wine > Cava : 38
# Champagne & Sparkling Wine > Flavored Sparkling Wine : 34
# Champagne & Sparkling Wine > Muscat/Moscato : 30
# Christmas > Christmas : 5396
# Cider > Apple Cider : 117
# Cider > Other Fruit Cider : 79
# Cider > Perry (Pear Cider) : 22
# Coolers & Malt Beverages > Flavored Malt Beverages : 58
# Coolers & Malt Beverages > Wine Coolers : 5
# Dairy & Eggs > Yogurt : 1815
# Dairy & Eggs > Packaged Cheese : 1602
# Dairy & Eggs > Milk : 707
# Dairy & Eggs > Soy & Lactose-Free : 559
# Dairy & Eggs > Other Creams & Cheeses : 417
# Dairy & Eggs > Cream : 349
# Dairy & Eggs > Butter : 289
# Dairy & Eggs > Refrigerated Pudding & Desserts : 187
# Dairy & Eggs > Eggs : 179
# Dairy & Eggs > Dairy Alternatives : 115
# Dairy & Eggs > Tofu & Meat Alternatives : 72
# Deli > Prepared Meals : 1280
# Deli > Specialty Cheeses : 955
# Deli > Lunch Meat : 837
# Deli > Prepared Soups & Salads : 445
# Deli > Fresh Dips & Tapenades : 419
# Deli > Tofu & Meat Alternatives : 103
# Deli > Deli Meat : 84
# Deli > Newly Added : 5
# Dessert & Fortified Wine > Port : 72
# Dessert & Fortified Wine > Vermouth : 34
# Dessert & Fortified Wine > Bordeaux Blend : 32
# Dessert & Fortified Wine > Mead : 27
# Dessert & Fortified Wine > Aperitif : 25
# Dessert & Fortified Wine > Sherry : 22
# Dessert & Fortified Wine > Riesling : 13
# Dessert & Fortified Wine > Other Dessert & Fortified Wines : 11
# Dessert & Fortified Wine > Muscat/Muscadine : 10
# Dessert & Fortified Wine > Fruit-Based Dessert Wine : 8
# Dessert & Fortified Wine > Ice Wine : 8
# Dessert & Fortified Wine > Red Blend Dessert Wine : 7
# Dessert & Fortified Wine > White Blend Dessert Wine : 6
# Dessert & Fortified Wine > Chocolate Wine : 3
# Dessert & Fortified Wine > Marsala : 3
# Dessert & Fortified Wine > Madeira : 2
# Dry Goods & Pasta > Instant Foods : 1033
# Dry Goods & Pasta > Dry Pasta : 753
# Dry Goods & Pasta > Pasta Sauce : 713
# Dry Goods & Pasta > Grains, Rice & Dried Goods : 606
# Dry Goods & Pasta > Fresh Pasta : 183
# Dry Goods & Pasta > Spices & Seasoning : 7
# Dry Goods & Pasta > Whole & Ground Seeds : 3
# Dry Goods & Pasta > Baking Supplies : 1
# Food > Chocolate, Candy & Mints : 8
# Food > Nuts : 6
# Food > Oils & Vinegars : 2
# Food > Cheese : 1
# Food > Chips, Puffs & Pretzels : 1
# Food > Condiments : 1
# Frozen > Ice Cream & Ice : 2508
# Frozen > Frozen Meals : 1956
# Frozen > Frozen Produce : 706
# Frozen > Frozen Appetizers & Sides : 685
# Frozen > Frozen Pizza : 594
# Frozen > Frozen Meat & Seafood : 481
# Frozen > Frozen Breakfast : 477
# Frozen > Frozen Vegan & Vegetarian : 378
# Frozen > Frozen Dessert : 296
# Frozen > Frozen Juice : 162
# Frozen > Frozen Breads & Doughs : 113
# Fruit Wine > Fruit Blends : 34
# Fruit Wine > Sangria : 26
# Gift Baskets & Sets > Gift Sets : 5
# Gift Baskets & Sets > Gift Baskets : 3
# Glassware & Accessories > Wine Glassware : 36
# Glassware & Accessories > Wine Accessories : 33
# Glassware & Accessories > Bar Tools : 25
# Glassware & Accessories > Other Glassware : 14
# Glassware & Accessories > Spirits Glassware : 14
# Glassware & Accessories > Beer Glassware : 6
# Glassware & Accessories > Wine Storage & Transport : 5
# Grocery > Frozen : 28
# Grocery > Pasta & Pasta Sauce : 12
# Grocery > Instant Foods : 7
# Grocery > Nuts : 7
# Grocery > Bars : 2
# Grocery > Bakery & Bread : 1
# Grocery > Sugar & Sugar Substitutes : 1
# Holiday Favorites > Produce : 33
# Holiday Favorites > Holiday Pantry : 22
# Holiday Favorites > Cheese & Appetizers : 11
# Holiday Favorites > Candles & Kitchenwares : 9
# Holiday Favorites > Desserts & Bakery : 6
# Holiday Favorites > Entrees : 5
# Holiday Favorites > Beverages : 3
# Holiday Favorites > Sides & Salads : 3
# Household > More Household : 3869
# Household > Cleaning Products : 1528
# Household > Kitchen Supplies : 1149
# Household > Laundry : 1044
# Household > Air Fresheners & Candles : 793
# Household > Food Storage : 628
# Household > Paper Goods : 596
# Household > Plates, Bowls, Cups & Flatware : 496
# Household > Dish Detergents : 391
# Household > Trash Bags & Liners : 173
# Household > Garden : 59
# Household > Books & Magazines : 1
# International > Asian Foods : 942
# International > Latino Foods : 480
# International > Kosher Foods : 178
# International > Indian Foods : 149
# International > More International Foods : 22
# Lager Beer > American-Style Lager : 104
# Lager Beer > Czech & German Pilsner : 73
# Lager Beer > Light Lager : 55
# Lager Beer > Euro Pale Lager : 41
# Lager Beer > Other Dark Lager : 25
# Lager Beer > Other Pale Lager : 23
# Lager Beer > American All-Malt Lager : 16
# Lager Beer > Amber/Red Lager : 14
# Lager Beer > Bock/Doppelbock/Maibock : 9
# Lager Beer > Japanese Rice Lager : 4
# Liqueurs/Cordials/Schnapps > Herbal & Spice : 112
# Liqueurs/Cordials/Schnapps > Citrus & Triple Sec : 74
# Liqueurs/Cordials/Schnapps > Cream : 64
# Liqueurs/Cordials/Schnapps > Fruit : 63
# Liqueurs/Cordials/Schnapps > Chocolate; Sweets & Candy : 49
# Liqueurs/Cordials/Schnapps > Nuts & Amaretto : 37
# Liqueurs/Cordials/Schnapps > Coffee : 32
# Liqueurs/Cordials/Schnapps > Fruit Blends : 27
# Liqueurs/Cordials/Schnapps > Unique Flavors : 13
# Liqueurs/Cordials/Schnapps > Other : 12
# Liqueurs/Cordials/Schnapps > Coconut : 4
# Meat & Seafood > Hot Dogs, Bacon & Sausage : 922
# Meat & Seafood > Packaged Meat : 633
# Meat & Seafood > Meat Counter : 397
# Meat & Seafood > Packaged Poultry : 304
# Meat & Seafood > Packaged Seafood : 215
# Meat & Seafood > Meat : 205
# Meat & Seafood > Poultry Counter : 163
# Meat & Seafood > Seafood Counter : 163
# Meat & Seafood > Seafood : 68
# Meat & Seafood > Poultry : 46
# Mixers, Water & Soda > Water : 40
# Mixers, Water & Soda > Tonic Water : 11
# Mixers, Water & Soda > Bitters : 9
# Mixers, Water & Soda > Cocktail Mixes : 8
# Mixers, Water & Soda > Juice : 8
# Mixers, Water & Soda > Sparkling Cider : 8
# Mixers, Water & Soda > Soda : 5
# Mixers, Water & Soda > Club Soda : 4
# Mixers, Water & Soda > Seltzer Water : 3
# Mixers, Water & Soda > Cocktail Rimmers : 1
# Mixers, Water & Soda > Sports Drinks : 1
# Mixers, Water & Soda > Syrups : 1
# Pantry > Spices & Seasonings : 1978
# Pantry > Condiments : 1473
# Pantry > Salad Dressing & Toppings : 1187
# Pantry > Baking Ingredients : 1158
# Pantry > Spreads : 975
# Pantry > Oils & Vinegars : 950
# Pantry > Marinades & Meat Preparation : 890
# Pantry > Doughs, Gelatins & Bake Mixes : 833
# Pantry > Pickled Goods & Olives : 784
# Pantry > Baking Supplies & Decor : 744
# Pantry > Preserved Dips & Spreads : 629
# Pantry > Honeys, Syrups & Nectars : 465
# Personal Care > Beauty : 5648
# Personal Care > Hair Care : 4343
# Personal Care > Vitamins & Supplements : 4217
# Personal Care > Body Lotions & Soap : 2413
# Personal Care > Oral Hygiene : 1976
# Personal Care > Facial Care : 1631
# Personal Care > Cold, Flu & Allergy : 1216
# Personal Care > First Aid : 1162
# Personal Care > Digestion : 1139
# Personal Care > Feminine Care : 1108
# Personal Care > Muscles, Joints & Pain Relief : 977
# Personal Care > Deodorants : 875
# Personal Care > Shave Needs : 765
# Personal Care > Protein & Meal Replacements : 722
# Personal Care > Eye & Ear Care : 651
# Personal Care > Soap : 299
# Personal Care > Family Planning : 258
# Personal Care > Stress & Sleep Aids : 258
# Personal Care > Skin Care : 250
# Personal Care > Hand Care : 244
# Personal Care > Foot Care : 138
# Personal Care > Air Fresheners & Candles : 94
# Personal Care > Adult Care : 67
# Personal Care > Oils & Tinctures : 52
# Personal Care > Medical Supplies/Aid : 40
# Personal Care > Clothing : 34
# Personal Care > Aromatherapy : 31
# Personal Care > Cleanses & Detoxes : 28
# Personal Care > Sun Care : 12
# Pets > Dog Food & Care : 1545
# Pets > Cat Food & Care : 1282
# Pets > Small Animal Care : 150
# Produce > Fresh Vegetables : 1186
# Produce > Packaged Vegetables & Fruits : 993
# Produce > Fresh Fruits : 721
# Produce > Fresh Herbs : 141
# Produce > Tofu & Meat Alternatives : 2
# Ready to Drink > Margaritas : 23
# Ready to Drink > Unique Cocktails : 13
# Ready to Drink > Daiquiris & Rum Drinks : 12
# Ready to Drink > Other : 12
# Ready to Drink > Lemonades & Citrus Drinks : 11
# Ready to Drink > Shots : 9
# Ready to Drink > Chocolate & Cream Drinks : 7
# Ready to Drink > Tea : 5
# Ready to Drink > Mojito : 2
# Ready to Drink > Cosmopolitan : 1
# Ready to Drink > Manhattans & Bourbon Drinks : 1
# Red Wine > Cabernet Sauvignon : 652
# Red Wine > Red Blend : 363
# Red Wine > Pinot Noir : 310
# Red Wine > Bordeaux Blend : 194
# Red Wine > Merlot : 187
# Red Wine > Sangiovese : 163
# Red Wine > Syrah/Shiraz : 147
# Red Wine > Rhone Blend : 96
# Red Wine > Tempranillo : 93
# Red Wine > Zinfandel : 93
# Red Wine > Malbec : 85
# Red Wine > Other Red Wines : 77
# Red Wine > Nebbiolo : 44
# Red Wine > Grenache : 32
# Red Wine > Cabernet Franc : 24
# Red Wine > Gamay : 22
# Red Wine > Corvina : 21
# Red Wine > Barbera : 18
# Red Wine > Petite Sirah : 17
# Red Wine > Montepulciano : 16
# Red Wine > Carmenere : 11
# Red Wine > Mourvedre/Monastrell : 7
# Rum > Aged Rum : 70
# Rum > Flavored Rum : 66
# Rum > Spiced Rum : 52
# Rum > Silver Rum : 42
# Rum > Gold Rum : 22
# Rum > Dark Rum : 16
# Rum > Other : 7
# Rum > Cachaca : 6
# Sake & Plum Wine > Sake : 39
# Sake & Plum Wine > Plum Wine : 6
# Scotch > Single Malt : 101
# Scotch > Blended Scotch : 91
# Seasonal/Special Release Beer > Seasonal : 135
# Seasonal/Special Release Beer > Special Release : 79
# Snacks > Candy & Chocolate : 3058
# Snacks > Chips & Pretzels : 1959
# Snacks > Energy & Granola Bars : 1705
# Snacks > Cookies & Cakes : 1645
# Snacks > Nuts, Seeds & Dried Fruit : 1395
# Snacks > Crackers : 1320
# Snacks > Popcorn & Jerky : 766
# Snacks > Mint & Gum : 498
# Snacks > Fruit & Vegetable Snacks : 464
# Snacks > Trail Mix & Snack Mix : 253
# Snacks > Ice Cream Toppings : 190
# Specialty Style Beer > Specialty Beer : 53
# Specialty Style Beer > Fruit Beer : 37
# Specialty Style Beer > Herbed/Spiced Beer : 21
# Specialty Style Beer > Shandy/Radler : 14
# Specialty Style Beer > American Wild Ale : 8
# Specialty Style Beer > Cream Ale : 3
# Specialty Style Beer > Chili Beer : 2
# Tequila > Blanco/Silver : 94
# Tequila > Reposado : 72
# Tequila > Anejo : 58
# Tequila > Flavored Tequila : 15
# Tequila > Gold : 12
# Tequila > Extra Anejo : 6
# Tequila > Other : 2
# Variety Packs > Variety Packs : 22
# Variety Packs > Gift Sets : 9
# Vodka > Vodka : 324
# Vodka > Flavored Vodka : 262
# Vodka > Other : 9
# Vodka > Variety Packs : 1
# White Wine > Chardonnay : 405
# White Wine > Riesling : 91
# White Wine > Sauvignon Blanc : 88
# White Wine > Pinot Grigio/Pinot Gris : 76
# White Wine > White Blend : 67
# White Wine > Other White Wines : 56
# White Wine > Muscat/Moscato : 40
# White Wine > Chenin Blanc : 18
# White Wine > Bordeaux Blend : 17
# White Wine > Gewurztraminer : 16
# White Wine > Viognier : 16
# White Wine > Rhone Blend : 11
# White Wine > Albarino : 10
# White Wine > Gruner Veltliner : 9
# White Wine > Garganega : 6
# White Wine > Torrontes : 5
# White Wine > Pinot Blanc : 4

# %% [markdown]
# # 6. Generate a new file where mrp is normalized. If there is a 0 or a non-float value or the key doesn't exist, make it "NA".

# %% [markdown]
# Normalization by formula: for yesterday's file

# %%
data=yd
data["mrp"]=((data["mrp"]-data["mrp"].min())/(data["mrp"].max()-data["mrp"].min()))
data.mrp
data["mrp"].replace(0,np.nan,inplace=True)
data.mrp
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7         0.089909
# 8         0.029903
# 9         0.052905
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
#             ...
# 141669         NaN
# 141670         NaN
# 141671         NaN
# 141672         NaN
# 141673         NaN
# 141674         NaN
# 141675         NaN
# 141676         NaN
# 141677         NaN
# 141678         NaN
# 141679         NaN
# 141680         NaN
# 141681         NaN
# 141682         NaN
# 141683         NaN
# 141684         NaN
# 141685         NaN
# 141686         NaN
# 141687         NaN
# 141688         NaN
# 141689         NaN
# 141690         NaN
# 141691         NaN
# 141692         NaN
# 141693         NaN
# 141694         NaN
# 141695         NaN
# 141696         NaN
# 141697         NaN
# 141698         NaN
# Name: mrp, Length: 141699, dtype: float64

# %% [markdown]
# Normalization using SKLEARN library: for both files

# %%
t = td[['mrp']].values.astype(float)
min_max_scaler = MinMaxScaler()
t_scaled = min_max_scaler.fit_transform(t)
t_mrp_normalized = pd.DataFrame(t_scaled)
t_mrp_normalized[0].replace((0,' '),np.nan,inplace=True)
print ("The normalized mrp values are: ")
t_mrp_normalized
# Out:
# The normalized mrp values are:
#                0
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7       0.089909
# 8       0.029903
# 9       0.052905
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# ...          ...
# 142261       NaN
# 142262       NaN
# 142263       NaN
# 142264       NaN
# 142265       NaN
# 142266       NaN
# 142267       NaN
# 142268       NaN
# 142269       NaN
# 142270       NaN
# 142271       NaN
# 142272       NaN
# 142273       NaN
# 142274       NaN
# 142275       NaN
# 142276       NaN
# 142277       NaN
# 142278       NaN
# 142279       NaN
# 142280       NaN
# 142281       NaN
# 142282       NaN
# 142283       NaN
# 142284       NaN
# 142285       NaN
# 142286       NaN
# 142287       NaN
# 142288       NaN
# 142289       NaN
# 142290       NaN
#
# [142291 rows x 1 columns]

# %%
td_NEW = td
td_NEW['mrp'] = t_mrp_normalized[0]
print ("The new today's file with normalized MRP values: ")
td_NEW.head()
# Out:
# The new today's file with normalized MRP values:
#    available_price   category  crawl_date  http_status  mrp pack_size  \
# 0             5.99  Household    20180727          200  NaN     30 ct
# 1             5.49  Household    20180727          200  NaN     25 ct
# 2             5.69  Household    20180727          200  NaN   30.0 ct
# 3             5.99  Household    20180727          200  NaN     12 ct
# 4             5.99  Household    20180727          200  NaN     20 ct
#
#            subcategory                                              title  \
# 0  Trash Bags & Liners  Seventh Generation 13 Gallon Extra Strong Flap...
# 1  Trash Bags & Liners  BioBag Food Scrap Bags Small 3 Gallon - 25 CT ...
# 2  Trash Bags & Liners  If You Care Certified Compostable Food Waste B...
# 3  Trash Bags & Liners  BioBag Food Scrap Bags Tall Kitchen 13 Gallon ...
# 4  Trash Bags & Liners  Seventh Generation 13 Gal with Drawstring Clos...
#
#                                        urlh  is_urlh_duplicate
# 0  1ef0f41ebcee030a35440405f2f8b0165c719c89              False
# 1  c566570abdbe95b5e6a78eb8b3b2424108bf36a2              False
# 2  3b22b28b351dec75664b17fcf586023ddc21704c              False
# 3  7ff787f49e137237054f95e7cb5b0f8611e7f6fb              False
# 4  a7ad16e71257855c033aad46eb5082a2153b97c6              False

# %%
y = yd[['mrp']].values.astype(float)
min_max_scaler = MinMaxScaler()
y_scaled = min_max_scaler.fit_transform(y)
y_mrp_normalized = pd.DataFrame(y_scaled)
y_mrp_normalized[0].replace((0,' '),np.nan,inplace=True)
print ("The normalized mrp values are: ")
y_mrp_normalized
# Out:
# The normalized mrp values are:
#                0
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7       0.085978
# 8       0.025713
# 9       0.048815
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# ...          ...
# 141669       NaN
# 141670       NaN
# 141671       NaN
# 141672       NaN
# 141673       NaN
# 141674       NaN
# 141675       NaN
# 141676       NaN
# 141677       NaN
# 141678       NaN
# 141679       NaN
# 141680       NaN
# 141681       NaN
# 141682       NaN
# 141683       NaN
# 141684       NaN
# 141685       NaN
# 141686       NaN
# 141687       NaN
# 141688       NaN
# 141689       NaN
# 141690       NaN
# 141691       NaN
# 141692       NaN
# 141693       NaN
# 141694       NaN
# 141695       NaN
# 141696       NaN
# 141697       NaN
# 141698       NaN
#
# [141699 rows x 1 columns]

# %%
yd_NEW = yd
yd_NEW['mrp'] = y_mrp_normalized[0]
print ("The new yesterday's file with normalized MRP values: ")
yd_NEW.head()
# Out:
# The new yesterday's file with normalized MRP values:
#    available_price   category  crawl_date  http_status  mrp pack_size  \
# 0             5.99  Household    20180726          200  NaN     30 ct
# 1             5.49  Household    20180726          200  NaN     25 ct
# 2             5.69  Household    20180726          200  NaN   30.0 ct
# 3             5.99  Household    20180726          200  NaN     12 ct
# 4             5.99  Household    20180726          200  NaN     20 ct
#
#            subcategory                                              title  \
# 0  Trash Bags & Liners  Seventh Generation 13 Gallon Extra Strong Flap...
# 1  Trash Bags & Liners  BioBag Food Scrap Bags Small 3 Gallon - 25 CT ...
# 2  Trash Bags & Liners  If You Care Certified Compostable Food Waste B...
# 3  Trash Bags & Liners  BioBag Food Scrap Bags Tall Kitchen 13 Gallon ...
# 4  Trash Bags & Liners  Seventh Generation 13 Gal with Drawstring Clos...
#
#                                        urlh  is_urlh_duplicate
# 0  1ef0f41ebcee030a35440405f2f8b0165c719c89              False
# 1  c566570abdbe95b5e6a78eb8b3b2424108bf36a2              False
# 2  3b22b28b351dec75664b17fcf586023ddc21704c              False
# 3  7ff787f49e137237054f95e7cb5b0f8611e7f6fb              False
# 4  a7ad16e71257855c033aad46eb5082a2153b97c6              False
