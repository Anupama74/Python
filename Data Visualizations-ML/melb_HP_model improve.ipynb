# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
meldf = pd.read_csv("melb_data.csv", index_col=0)
meldf.head(5)
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 1  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 4  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 5  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 6  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode      ...       Bathroom  Car  Landsize  \
# 1  3/12/2016       2.5    3067.0      ...            1.0  1.0     202.0
# 2  4/02/2016       2.5    3067.0      ...            1.0  0.0     156.0
# 4  4/03/2017       2.5    3067.0      ...            2.0  0.0     134.0
# 5  4/03/2017       2.5    3067.0      ...            2.0  1.0      94.0
# 6  4/06/2016       2.5    3067.0      ...            1.0  2.0     120.0
#
#    BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 1           NaN        NaN        Yarra  -37.7996    144.9984
# 2          79.0     1900.0        Yarra  -37.8079    144.9934
# 4         150.0     1900.0        Yarra  -37.8093    144.9944
# 5           NaN        NaN        Yarra  -37.7969    144.9969
# 6         142.0     2014.0        Yarra  -37.8072    144.9941
#
#               Regionname Propertycount
# 1  Northern Metropolitan        4019.0
# 2  Northern Metropolitan        4019.0
# 4  Northern Metropolitan        4019.0
# 5  Northern Metropolitan        4019.0
# 6  Northern Metropolitan        4019.0
#
# [5 rows x 21 columns]

# %%
meldf.describe()
print (sklearn.__version__)
# Out:
# 0.19.1

# %%
meldf.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
#meldf = meldf.dropna(axis=0)
#meldf.describe()
# Out:
#              Rooms         Price     Distance     Postcode     Bedroom2  \
# count  6196.000000  6.196000e+03  6196.000000  6196.000000  6196.000000
# mean      2.931407  1.068828e+06     9.751097  3101.947708     2.902034
# std       0.971079  6.751564e+05     5.612065    86.421604     0.970055
# min       1.000000  1.310000e+05     0.000000  3000.000000     0.000000
# 25%       2.000000  6.200000e+05     5.900000  3044.000000     2.000000
# 50%       3.000000  8.800000e+05     9.000000  3081.000000     3.000000
# 75%       4.000000  1.325000e+06    12.400000  3147.000000     3.000000
# max       8.000000  9.000000e+06    47.400000  3977.000000     9.000000
#
#           Bathroom          Car      Landsize  BuildingArea    YearBuilt  \
# count  6196.000000  6196.000000   6196.000000   6196.000000  6196.000000
# mean      1.576340     1.573596    471.006940    141.568645  1964.081988
# std       0.711362     0.929947    897.449881     90.834824    38.105673
# min       1.000000     0.000000      0.000000      0.000000  1196.000000
# 25%       1.000000     1.000000    152.000000     91.000000  1940.000000
# 50%       1.000000     1.000000    373.000000    124.000000  1970.000000
# 75%       2.000000     2.000000    628.000000    170.000000  2000.000000
# max       8.000000    10.000000  37000.000000   3112.000000  2018.000000
#
#          Lattitude   Longtitude  Propertycount
# count  6196.000000  6196.000000    6196.000000
# mean    -37.807904   144.990201    7435.489509
# std       0.075850     0.099165    4337.698917
# min     -38.164920   144.542370     389.000000
# 25%     -37.855438   144.926198    4383.750000
# 50%     -37.802250   144.995800    6567.000000
# 75%     -37.758200   145.052700   10175.000000
# max     -37.457090   145.526350   21650.000000

# %%
#sns.kdeplot(reviews.query('price < 200').price)
#sns.countplot(meldf.query('Bathroom < 6').Bathroom)

from sklearn.impute import SimpleImputer
my_imputer = SimpleImputer()
meldf = my_imputer.fit_transform(meldf)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-049567732949> in <module>()
#       2 #sns.countplot(meldf.query('Bathroom < 6').Bathroom)
#       3
# ----> 4 from sklearn.impute import SimpleImputer
#       5 my_imputer = SimpleImputer()
#       6 meldf = my_imputer.fit_transform(meldf)
#
# ModuleNotFoundError: No module named 'sklearn.impute'

# %%
#print(df.loc[df['A'] == 'foo'])
#meldf=meldf.loc[meldf['Bathroom'] <=5]
#meldf=meldf.loc[meldf['Price'] <=7000000]
#meldf=meldf.loc[meldf['Landsize'] <=20000]

# %%
sns.countplot(meldf['Bathroom'])

# %%
meldf['Rooms'].head(30).plot.bar()   #YearBuilt

# %%
meldf.plot.scatter(x='Price',y='Rooms')

# %%
meldf.plot.scatter(x='Price',y='Bathroom')

# %%
sns.pairplot(meldf[['Price','Rooms', 'Bathroom', 'Lattitude','Longtitude','Landsize']])

# %%
meldf.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF4EC4208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF4EFECF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF4F2E048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF4F59358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF4F82668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF4F826A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF4FD6C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5000F98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF4879D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF503EF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5070668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5097CF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF50C83C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF50F0A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5121128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF51497B8>]],
#       dtype=object)

# %%
pd.scatter_matrix(meldf)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5339A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF53AD5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5404208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5429898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5451F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5451F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF54A9C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF54D9358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF54FF9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF55330B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5559748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF557FDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF55B24A8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF55DBB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF560A208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5631898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF565AF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF568B5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF56B0C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF56E2358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF570A9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF573D0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5765748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF578BDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF57BF4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF57E7B38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5816208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF583C8D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5866F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF58955F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF58BEC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF58F1358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF59179E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF59470B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF596E748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5997DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF59C94A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF59F0B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5A21208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5A49898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5A70F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5AA15F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5AC9C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5AFA358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5B239B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5B53080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5B7A710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5BA3DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5BCADA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5BFD470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5C24B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5C561D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5C7C860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5CA6EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5CD75C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5D00C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5D31320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5D599B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5D8C080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5DB3710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5DDCDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5E0D470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5E34B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5E681D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5E8F860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5EB8EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5EE95C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5F12C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5F43320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF5F699B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF6F6D080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF6F96710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF6FC0DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF6FF1470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7016B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF704B1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7071860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7098EF0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF70CC5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF70F6C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7125320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF714D9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7181080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF71A7710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF71CFDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7202470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7228B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF725C1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7285860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF72ADEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF72DD5C0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7305C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7336320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF735E9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7390080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF73BB710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF73E3DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7414470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF743CB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF746F1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7495860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF74BFEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF74F05C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7519C50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF754B320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF75729B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF75A3080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF75CB710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF75F3DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7624470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF764CB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF76821D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF76A8860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF76D0EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF77025C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7728C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF775B320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF77829B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF77B6080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF77DF710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7806DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF783A470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7861B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF78921D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF78BB860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF78E3EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF79145C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF793EC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7970320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF79979B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF79C9080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF79F0710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7A19DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7A4A470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7A71B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7AA51D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7ACE860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7AF5EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7B255C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7B50C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7B82320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7BA99B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7BDA080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7C04710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7C2CDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7C5E470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7C85B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7CB71D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7CDE860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7D07EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7D385C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7D62C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7D95320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7DBA9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7DEF080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7E14710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7E3CDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7E6F470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7E97B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7ECA1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7EF0860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7F1AEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7F4B5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7F72C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7FA5320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7FCE9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF7FFF080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF8029710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EF8050DA0>]],
#       dtype=object)

# %%
#sns.lmplot(x='Rooms',y='Landsize', hue='Price', fit_reg=False, data=meldf)

# %%
y = meldf.Price
y.head()
# Out:
# 2     1035000.0
# 4     1465000.0
# 6     1600000.0
# 11    1876000.0
# 14    1636000.0
# Name: Price, dtype: float64

# %%
x = meldf[['Rooms', 'Bathroom', 'Lattitude','Longtitude','Landsize']]
x.describe()
plots = meldf[['Price','Rooms', 'Bathroom', 'Landsize','YearBuilt', 'Lattitude', 'Longtitude']]

# %%
x.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFF82D668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFF857400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFF87F710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFF799320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFF8CBF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFF8CBF98>]],
#       dtype=object)

# %%
pd.scatter_matrix(plots)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFA00080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFA40550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFA67BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFA992B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFAC0940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFAC0978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFB196A0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFB42D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFB71400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFB99A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFBCB160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFBF17F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFC19E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFC4A550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFC70BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFCA1278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFCCA908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFCF2F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFD20668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFD49CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFD7B3C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFDA0A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFDD5128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFDFD7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFE23E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFE52518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFE7BBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFEAB278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFED3908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFEFBF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFF2D668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFF56CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFF853C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFFFADA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027E80FE0128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027E810067B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027E8102EE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027E8105F518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027E81085BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027E810B7278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027E810DF908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027E81108F98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027E81137668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027E8115FCF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027E811913C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027E811B8A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027E811EC128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027E812137B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027E8123DE48>]],
#       dtype=object)

# %%
plots.plot(kind='density',subplots=True, sharex=False, sharey=False, figsize=(5,4), colormap='Spectral')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFF1A0BA8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFF1EDC50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFF21E320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFF2439B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFF276080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFF2760B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000027EFF2C4DA0>],
#       dtype=object)

# %%
corln = meldf.corr()['Price']
print(corln)
# Out:
# Rooms            0.541999
# Price            1.000000
# Distance        -0.155279
# Postcode         0.127152
# Bedroom2         0.526373
# Bathroom         0.514750
# Car              0.261600
# Landsize         0.102014
# BuildingArea     0.537528
# YearBuilt       -0.305358
# Lattitude       -0.216824
# Longtitude       0.212776
# Propertycount   -0.048081
# Name: Price, dtype: float64

# %%
sns.regplot(x='Price',y='Rooms',data=meldf)
plt.ylim(0)
# Out:
# (0, 8.354890344233116)

# %%
from sklearn.model_selection import train_test_split
x_tr,x_tes,y_tr,y_tes = train_test_split (x,y,test_size=0.25, random_state =0)

# %%
# Define model. Specify a number for random_state to ensure same results each run
model = RandomForestRegressor(random_state=1)
#RandomForestRegressor
# Fit model:      DecisionTreeRegressor
model.fit(x_tr, y_tr)
#coeff_df = pd.DataFrame(model.coef_,x.columns,columns = ['Coefficient'])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
y_pred=model.predict(x_tes)
print(y_pred)
# Out:
# [1380950.  861000.  415400. ...  386100.  615650.  725900.]

# %%
print("Making predictions for the following 5 houses:")
#print (x_tes.head(5))
print("The predictions are")
#print (y_pred)
index=x_tes.index
result = pd.DataFrame (y_pred,index)
print (result)
# Out:
# Making predictions for the following 5 houses:
# The predictions are
#                0
# 7824   1380950.0
# 17263   861000.0
# 5775    415400.0
# 5487    689000.0
# 18915   445600.0
# 10637  1562800.0
# 12626   533227.6
# 10218  1342000.0
# 9003    766200.0
# 749     648300.0
# 13115  1449600.0
# 2117    994801.0
# 4505   3697000.0
# 8635    543150.0
# 15911  1168650.0
# 15593   918000.0
# 14489   682400.0
# 4267   1718500.0
# 15699   628800.0
# 789     740400.0
# 3336    779650.0
# 13743   568850.0
# 18494  1308200.0
# 2286    966900.0
# 17526   706100.0
# 10062  1606000.0
# 16489  1019950.0
# 10297  1153100.0
# 18929   703400.0
# 7734    922900.0
# ...          ...
# 4126   1111300.0
# 14316   956600.0
# 230     754700.0
# 10652  1275400.0
# 3402   1158600.0
# 15500   319400.0
# 623    2123300.0
# 12056  1445850.0
# 13022   654000.0
# 11810   671500.0
# 18910   507150.0
# 4165    609900.0
# 6869   1294450.0
# 12513  1639600.0
# 10510  1218800.0
# 5513    476400.0
# 2357   1157200.0
# 6827    507300.0
# 10942   877150.0
# 5533    834900.0
# 1001    697090.0
# 9479    649500.0
# 13146   691350.0
# 4909    392550.0
# 6083   3157000.0
# 11397  1711500.0
# 3176    810100.0
# 8948    386100.0
# 10658   615650.0
# 16216   725900.0
#
# [1547 rows x 1 columns]

# %%
prediction_graph = pd.DataFrame({'Original':y_tes,'Predicted':y_pred})
prediction_graph.plot(kind='density',sharex=True)

# %%
sns.residplot(y_tes,x_tes['Bathroom'],color='black',label='Actual data')
sns.residplot(y_pred,x_tes['Bathroom'],color='Red',label='fitted data')

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_tes, y_pred))  
print('R2:', metrics.r2_score(y_tes,y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_tes, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_tes, y_pred)))
# Out:
# Mean Absolute Error: 195400.31376858434
# R2: 0.7603527034435567
# Mean Squared Error: 99191543078.31445
# Root Mean Squared Error: 314946.8892977266

# %%
def get_mae(max_leaf_nodes,x_tr, x_tes,y_tr, y_tes):
    model = RandomForestRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(x_tr,y_tr)
    preds_val = model.predict(x_tes)
    mae = metrics.mean_absolute_error(y_tes, preds_val)
    r2=metrics.r2_score(y_tes,preds_val)
    return (mae,r2)
for max_leaf_nodes in [5,10,100,250,500,1000,5000]:
    my_mae, R2= get_mae(max_leaf_nodes, x_tr, x_tes, y_tr, y_tes)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d \t\t  R2:  %f" %(max_leaf_nodes, my_mae,R2))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  354564 		  R2:  0.397580
# Max leaf nodes: 10  		 Mean Absolute Error:  300521 		  R2:  0.556965
# Max leaf nodes: 100  		 Mean Absolute Error:  213084 		  R2:  0.742418
# Max leaf nodes: 250  		 Mean Absolute Error:  195075 		  R2:  0.767353
# Max leaf nodes: 500  		 Mean Absolute Error:  188883 		  R2:  0.775424
# Max leaf nodes: 1000  		 Mean Absolute Error:  186245 		  R2:  0.777753
# Max leaf nodes: 5000  		 Mean Absolute Error:  186567 		  R2:  0.776962
