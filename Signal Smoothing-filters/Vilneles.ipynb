# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pywt

# %%
synthetic = np.loadtxt('synthetic.txt')

# %%
plt.plot(synthetic)

# %%
wavcoef = pywt.wavedec(synthetic, "haar", level=7)

# %%
plt.plot(wavcoef[0])

# %%
plt.plot(wavcoef[1])

# %%
plt.plot(wavcoef[2])

# %%
plt.plot(wavcoef[3])

# %%
plt.plot(wavcoef[4])

# %%
plt.plot(wavcoef[5])

# %%
plt.plot(wavcoef[6])

# %%
plt.plot(wavcoef[7])

# %%
recon = pywt.waverec(wavcoef, 'haar')

# %%
plt.plot(recon)
